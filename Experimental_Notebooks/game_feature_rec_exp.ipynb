# %% [markdown]
# ## Game Feature Recommendation System
# Recommends to the user on prompting game features extracted from game database information

# %%
# Library imports

import numpy as np
import spacy
import math
from nltk.tokenize import word_tokenize
from tqdm import tqdm
from nltk.corpus import stopwords
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances

nlp = spacy.load("en_core_web_sm")

# %%
# External data imports
def loadFeatData():
    DAT = {}
    with open("../data/game_datfeat.txt", "r") as f:
    # with open("../data/game_datfeat_FULL.txt", "r") as f:
        lines = [l.strip() for l in f.readlines()]
        CUR_GAME = ""
        for l in lines:
            # empty line (between entries)
            if l == "":
                continue
            #new entry
            else:
                if l[0] == "+":
                    CUR_GAME = l[2:]
                    DAT[CUR_GAME] = {"tags":[],"entities":[],"features":[]}
                elif l[0] == "#":
                    DAT[CUR_GAME]["tags"] = [t.lower() for t in l[2:].split(",")]
                elif l[0] == "@":
                    DAT[CUR_GAME]["entities"] = l[2:].split(",")
                elif l[0] == "-":
                    DAT[CUR_GAME]["features"].append(l[2:])
    return DAT


#get all of the tags and the entities from the game data
def getTagsEntities():
    # get all of the tags and entities
    ALL_TAGS = []
    ALL_ENTITIES = []
    for g in GAME_DATA:
        ALL_TAGS += [t.lower() for t in GAME_DATA[g]["tags"]]
        ALL_ENTITIES += [e.lower() for e in GAME_DATA[g]["entities"]]

    # remove duplicates
    ALL_TAGS = list(set(ALL_TAGS))
    ALL_ENTITIES = list(set(ALL_ENTITIES))

    return ALL_TAGS, ALL_ENTITIES


GAME_DATA = loadFeatData()
ALL_TAGS, ALL_ENTITIES = getTagsEntities()

# %% [markdown]
# ## EXPERIMENTS
# * Sample input text: "_top-down multiplayer action game about knights, castles, and assassinations_"
# * Target selection games: [Castle Crashers, Hammerwatch, Kingsway], Thief Gold, Skyrim, Elden Ring
#
# _Notes:_
# - Maybe having some not perfect predictions is necessary for the user to prevent from making cloned games? -> #5 has best predictions so far, but aren't spot on

# %%
# general functions
TRAIN_MODE = "WORD_EMB"
SENT_MODEL = None
custom_stopwords = ["game", ",", ".", "!"]

#setup abstract function
def getClosestGames(txt,k=3):
    return [("?",0)]

#tokenizes the text
def tokenize(txt):
    raw_toks = word_tokenize(txt)
    toks = [w.lower() for w in raw_toks if w.lower() not in stopwords.words("english") and w.lower() not in custom_stopwords]
    #add the custom tag words (can be compound words)
    for t in ALL_TAGS:
        if t in txt and t not in toks:
            toks.append(t)
    return toks

# %% [markdown]
# ### 1. VECTORIZE THE TAGS + ENTITIES
# - Note: Completely wrong. Vectorizing doesn't work with unbalanced dataset - picked the matches with fewest amount of data in vector
# - Result: ["The Ramp", "Batman: Arkham City", "Among Us"]

# %%
###   VECTOR THE TAGS AND ENTITIES   ###
if TRAIN_MODE == "VECTOR":

    # get all of the tags and entities
    ALL_TAGS = []
    ALL_ENTITIES = []
    for g in GAME_DATA:
        ALL_TAGS += [t.lower() for t in GAME_DATA[g]["tags"]]
        ALL_ENTITIES += [e.lower() for e in GAME_DATA[g]["entities"]]

    # remove duplicates
    ALL_TAGS = list(set(ALL_TAGS))
    ALL_ENTITIES = list(set(ALL_ENTITIES))

    #make a tag embedding
    def tagEmbed(tags):
        vec = [0]*len(ALL_TAGS)
        for t in tags:
            tt = t.lower()
            if tt in ALL_TAGS:
                vec[ALL_TAGS.index(tt)] = 1
        return vec

    #make a entity embedding
    def entEmbed(entities):
        vec = [0]*len(ALL_ENTITIES)
        for e in entities:
            ee = e.lower()
            if ee in ALL_ENTITIES:
                vec[ALL_ENTITIES.index(ee)] = 1
        return vec


    # make the embeddings for each game
    TAG_EMBEDDINGS = {}
    ENTITY_EMBEDDINGS = {}
    for g in GAME_DATA:
        TAG_EMBEDDINGS[g] = tagEmbed(GAME_DATA[g]["tags"])
        ENTITY_EMBEDDINGS[g] = entEmbed(GAME_DATA[g]["entities"])

    #make a combined embedding
    FULL_EMVEDDINGS = {}
    for g in GAME_DATA:
        FULL_EMVEDDINGS[g] = TAG_EMBEDDINGS[g]+ENTITY_EMBEDDINGS[g]


    ## GET CLOSEST GAME FROM TEXT BASED ON EMBEDDINGS ##
    def getClosestGames(txt,k=3):
        # tokenize and remove all stop words
        toks = tokenize(txt)
        # print(toks)

        # get the embedding for the text
        txt_embed = tagEmbed(toks)+entEmbed(toks)

        # get the closest games using distance metrics
        dists = {}
        for g in GAME_DATA:
            dists[g] = np.linalg.norm(np.array(txt_embed) - np.array(FULL_EMVEDDINGS[g]))
        dists = sorted(dists.items(), key=lambda x: x[1])
        # print(dists)
        return dists[:k], None

# %% [markdown]
# ### 2. COUNT THE MATCHES
# - Note: Doesn't get the right matches for the secondary choices - especially if the tags themselves are too general. No way to account for tie-breakers
# - Result: ["Castle Crashers", "Hammerwatch", "Among Us"]

# %%
# count the number of tags and entities matches 
if TRAIN_MODE == "COUNT":
    
    # get the closest games using count matches
    def getClosestGames(txt,k=3):
        # tokenize and remove all stop words
        toks = tokenize(txt)

        # initialize the counts
        cts = {}
        for g in GAME_DATA:
            cts[g] = 0
        
        # count the matches for each game
        matches = {}
        for t in toks:
            for g in GAME_DATA:
                if t in GAME_DATA[g]["tags"] or t in GAME_DATA[g]["entities"]:
                    cts[g] += 1
                    if g not in matches:
                        matches[g] = []
                    matches[g].append(t)

        # sort the counts
        cts = sorted(cts.items(), key=lambda x: x[1], reverse=True)
        return cts[:k], matches

# %% [markdown]
# ### 3. BERT SENTENCE TRANSFORMER MODEL
# - Note: Ok, but places too much weight on the word semantics themselves.
# - Result: ["Kingsway", "Hammerwatch", "Batman: Arkham City"]

# %%
if TRAIN_MODE == "TRANSFORMER":
    # load the model
    if SENT_MODEL == None:
        SENT_MODEL = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
if TRAIN_MODE == "TRANSFORMER":

    # turn game data into a "sentence" for the sentence-transformer
    def sentGame(g):
        return " ".join(GAME_DATA[g]["tags"])+" "+" ".join(GAME_DATA[g]["entities"])

    # encode the game data
    def encodeGames():
        emb_dat = {}
        with tqdm(total=len(GAME_DATA)) as pbar:
            for g in GAME_DATA:
                emb_dat[g] = SENT_MODEL.encode(sentGame(g))
                pbar.update(1)
        return emb_dat

    GAME_DAT_EMB = encodeGames()

# %%
if TRAIN_MODE == "TRANSFORMER":
    # find the closest game based on the encoded game data
    def getClosestGames(txt,k=3):
        # tokenize and remove all stop words
        toks = tokenize(txt)

        # encode the text
        txt_embed = SENT_MODEL.encode([" ".join(toks)])

        # get the closest games using distance metrics
        dists = {}
        for g in GAME_DATA:
            temb = np.array(txt_embed)
            gemb = np.array(GAME_DAT_EMB[g])
            dists[g] = cosine_similarity(temb,[gemb])
        dists = sorted(dists.items(), key=lambda x: x[1], reverse=True)
        # print(dists)
        return dists[:k], None

# %% [markdown]
# ### 4. TAG MATCH + SENTENCE TRANSFORMER SIMILARITY
# - Note: Ok, but has both problems of the counter and transformer experiments. Too much weight on tags, not enough on less frequently occuring entities
# - Result: ["Hammerwatch", "Binding of Isaac", "Castle Crashers"]

# %%
if TRAIN_MODE == "CT_TRANS":
    # load the model
    if SENT_MODEL == None:
        SENT_MODEL = SentenceTransformer('bert-base-nli-mean-tokens')

# %%
if TRAIN_MODE == "CT_TRANS":
    # turn game data into a "sentence" for the sentence-transformer
    def sentGame(g):
        return " ".join(GAME_DATA[g]["tags"])+" "+" ".join(GAME_DATA[g]["entities"])

    # encode the game data
    def encodeGames():
        emb_dat = {}
        with tqdm(total=len(GAME_DATA)) as pbar:
            for g in GAME_DATA:
                emb_dat[g] = SENT_MODEL.encode(sentGame(g))
                pbar.update(1)
        return emb_dat

    GAME_DAT_EMB = encodeGames()

    # count the number of tags found in each game's list
    def tagsFound(txt):
        # tokenize and remove all stop words
        toks = tokenize(txt)

        # initialize the counts
        cts = {}
        for g in GAME_DATA:
            cts[g] = 0
        
        # count the matches for each game
        for g in GAME_DATA:
            for t in toks:
                if t in GAME_DATA[g]["tags"]:
                    cts[g] += 1

        # sort the counts
        cts = dict(sorted(cts.items(), key=lambda x: x[1], reverse=True))
        return cts

# %%
if TRAIN_MODE == "CT_TRANS":
    # get the closest games using count matches and the sentence transformer distance metric
    def getClosestGames(txt,k=3):
        # tokenize and remove all stop words
        toks = tokenize(txt)

        # encode the text
        txt_embed = SENT_MODEL.encode([" ".join(toks)])

        # get the closest games using distance metrics
        dists = {}
        for g in GAME_DATA:
            temb = np.array(txt_embed)
            gemb = np.array(GAME_DAT_EMB[g])
            dists[g] = cosine_similarity(temb,[gemb])

        #multiply by the tag matches
        TAG_MATCHES = tagsFound(txt)
        print(TAG_MATCHES)
        for g in dists:
            dists[g] *= TAG_MATCHES[g]

        # sort by distance
        dists = sorted(dists.items(), key=lambda x: x[1], reverse=True)
        # print(dists)
        return dists[:k], None

# %% [markdown]
# ### 5. TF-IDF + SENTENCE TRANSFORMER SIMILARITY
# - Notes: Closer... Needs a mix of tf-idf with semantic similarity score that the transformer can offer
# - Result: ["Castle Crashers", "Hammerwatch", "Among Us"]

# %%
# TF-IDF Code heheh

#term frequency - how often a term appears in a document / total number of terms in the document
def tf(doc):  # assume doc is a list of words already tokenized
    tf_dict = {}
    for word in doc:
        if word not in tf_dict:
            tf_dict[word] = 1
        tf_dict[word] += 1
    for word in tf_dict:
        tf_dict[word] = tf_dict[word] / len(doc)
    return tf_dict

#inverse document frequency - log(total number of documents / number of documents with term t in it)
def idf(documents):  # assume documents is a list of lists of words already tokenized
    df = {}
    for doc in documents:  
        for word in doc:
            if word in df:
                df[word] += 1
            else:
                df[word] = 1

    idf_dict = {}
    for word in df:
        idf_dict[word] = math.log(len(documents) / df[word])
    return idf_dict
    
# get the full tfidf score for each word in each game's dataset
def tfidf(doc_set):  # assume doc_set is a dictionary of games with word lists already tokenized
    tfidf_dict = {}
    corpuses = [d for d in doc_set.values()]
    # print(corpuses)
    idf_dat = idf(corpuses)
    for game, doc in doc_set.items():
        tf_dat = tf(doc)
        tfidf_dict[game] = {}
        for word in doc:
            # tfidf_dict[game][word] = tf_dat[word] * idf_dat[word]   #note: the tf will be uniform for each word in a doc since it only saves unique words
            tfidf_dict[game][word] = idf_dat[word]
    return tfidf_dict

# %%
if TRAIN_MODE == "TFIDF_TRANS":
    # load the model
    if SENT_MODEL == None:
        SENT_MODEL = SentenceTransformer('bert-base-nli-mean-tokens')

    # turn game data into a "sentence" for the sentence-transformer
    def sentGame(g):
        return " ".join(GAME_DATA[g]["tags"])+" "+" ".join(GAME_DATA[g]["entities"])

    # encode the game data
    def encodeGames():
        emb_dat = {}
        with tqdm(total=len(GAME_DATA)) as pbar:
            for g in GAME_DATA:
                emb_dat[g] = SENT_MODEL.encode(sentGame(g))
                pbar.update(1)
        return emb_dat

    GAME_DAT_EMB = encodeGames()

    # get the tfidf scores for each game
    GAME_DOCS = {}
    for g in GAME_DATA:
        GAME_DOCS[g] = list(set(GAME_DATA[g]["tags"]+GAME_DATA[g]["entities"]))
    GAME_DAT_TFIDF = tfidf(GAME_DOCS)

# %%
if TRAIN_MODE == "TFIDF_TRANS":
    def getClosestGames(txt,k=3):
        # tokenize and remove all stop words
        toks = tokenize(txt)

        # encode the text
        txt_embed = SENT_MODEL.encode([" ".join(toks)])

        # get the closest games using distance metrics
        dists = {}
        for g in GAME_DATA:
            temb = np.array(txt_embed)
            gemb = np.array(GAME_DAT_EMB[g])
            dists[g] = cosine_similarity(temb,[gemb])

        #multiply by the tag matches
        # TAG_MATCHES = tagsFound(txt)
        # for g in dists:
        #     dists[g] *= TAG_MATCHES[g]

        # multiply by the tfidf scores
        for g in dists:
            for t in toks:
                if t in GAME_DAT_TFIDF[g]:
                    dists[g] += GAME_DAT_TFIDF[g][t]*10
                # else:
                #     dists[g] *= 0.0001

        # sort by distance
        dists = sorted(dists.items(), key=lambda x: x[1], reverse=True)
        # print(dists)
        return dists[:k], sorted([(d[0],d[1][0][0]) for d in dists], key=lambda x: x[1], reverse=True)

# %% [markdown]
# ### 6. WORD EMBEDDINGS
# * Notes:
#   * Use 50d - no result change with increase except longer execution time.
#   * Getting the average didn't work as intended.
#   * Getting the max of each row got much better results.
#   * Using tf-idf gets about the same results.
#   * Using without tag multiplier but including in word embedding gets more accurate top 5.
#   * Only using sum gets even better.
#   * Adding TF-IDF to the end gets even better results.
# * Results: ["Hammerwatch", "Castle Crashers", "Among Us"]

# %%
if TRAIN_MODE == "WORD_EMB":
    #import the word embedding data from the GloVe dataset
    GLOVE_DAT = {}
    with open("../data/glove.6B/glove.6B.50d.txt", "r", encoding="utf-8") as f:
        lines = f.readlines()
        with tqdm(total=len(lines)) as pbar:
            for line in lines:
                line = line.split()
                GLOVE_DAT[line[0]] = np.array([float(x) for x in line[1:]])
                pbar.update(1)

    # get the tfidf scores for each game
    GAME_DOCS = {}
    for g in GAME_DATA:
        GAME_DOCS[g] = list(set(GAME_DATA[g]["tags"]+GAME_DATA[g]["entities"]))
    GAME_DAT_TFIDF = tfidf(GAME_DOCS)
# Out:
# 100%|██████████| 400000/400000 [00:06<00:00, 65053.99it/s]

# %%
if TRAIN_MODE == "WORD_EMB":
    def sentGame(g):
        return " ".join(GAME_DATA[g]["tags"])+" "+" ".join(GAME_DATA[g]["entities"])

    # return the distance between 2 game theme word sets
    def gameThemeDist(g1,g2): 
        # both game has a set of theme words of varying lengths
        d = cosine_similarity([GLOVE_DAT[w] for w in g1 if w in GLOVE_DAT],[GLOVE_DAT[w] for w in g2 if w in GLOVE_DAT if w in GLOVE_DAT])

        #average the distance
        # return sum([sum(x) for x in d])/(len(g1)*len(g2))

        #return the average of the max for each word in g1
        return sum([max(x) for x in d])

    # return the distance between 2 game entity word sets with tf-idf weighting
    def gameThemeDistTFIDF(g1,g2,game):
        # both game has a set of theme words of varying lengths
        d = []
        for w1 in g1:
            di = []
            for w2 in g2:
                if w1 in GLOVE_DAT and w2 in GLOVE_DAT:
                    di.append(cosine_similarity([GLOVE_DAT[w1]],[GLOVE_DAT[w2]])[0][0]*GAME_DAT_TFIDF[game][w2])
            if len(di) > 0:
                d.append(di)

        return sum([max(x) for x in d])

    # get the closest games using the TF-IDF and word embedding distances
    def getClosestGames(txt,k=3):
        # tokenize and remove all stop words
        toks = tokenize(txt)
        entities = [t for t in toks if t not in ALL_TAGS]
        # print(f"ENTITIES: {entities}")

        # get the closest games using distance metrics
        dists = {}
        for g in GAME_DATA:
            dists[g] = gameThemeDist(toks,GAME_DATA[g]["tags"]+GAME_DATA[g]["entities"])   #use the theme words (entities + tags)
            # dists[g] = gameThemeDist(entities,GAME_DATA[g]["entities"])   #only use entities

        #multiply by the tag matches
        # TAG_MATCHES = tagsFound(txt)
        # for g in dists:
        #     dists[g] *= TAG_MATCHES[g]

        #add tf-idf scores where found
        for g in dists:
            for t in toks:
                if t in GAME_DAT_TFIDF[g]:
                    dists[g] += GAME_DAT_TFIDF[g][t]

        # sort by distance
        dists = sorted(dists.items(), key=lambda x: x[1], reverse=True)
        return dists[:k], sorted([(d[0],round(d[1],4)) for d in dists], key=lambda x: x[1], reverse=True)

# %% [markdown]
# ## RUN RECOMMENDATION SYSTEM
#
# #### Steps:
# 1. Load the data (games => tags, entities, features)
# 2. Get a user prompt for a game and its genre
# 3. Recommend some random features based on the text similarity and closest tags
#
# * Note: Keep in mind, there are over 150k games with tags, features, and entities - the search cannot be too large

# %%
# recommend some features to the user based on a prompt
def recommendFeatures(userPrompt):
    # get the closest game
    closestGames, other = getClosestGames(userPrompt)
    print(closestGames)

    #show more debug info
    if other:
        print(other)
        print("")

    # get the features for that game
    for i in closestGames:
        g,v = i
        print(f"{g} -> {v}")
        print(sentGame(g))
        print(GAME_DATA[g]["features"])
        print("")

# %%
user_txt = "top-down multiplayer action game about knights, castles, and assassinations"  #ideally should return "castle crashers" or "hammerwatch" or "thief"
print(tokenize(user_txt))
print("")
print(f"----- {TRAIN_MODE} -----")
print("")
recommendFeatures(user_txt)
# Out:
# ['top-down', 'multiplayer', 'action', 'knights', 'castles', 'assassinations', 'assassin']
#
# ----- WORD_EMB -----
#
# [('HOARD', 25.266873260011234), ('ROAD REDEMPTION', 23.061376032894227), ('ASSASSIN BLUE', 20.398141089807915)]
# [('HOARD', 25.2669), ('ROAD REDEMPTION', 23.0614), ('ASSASSIN BLUE', 20.3981), ("ASSASSIN'S CREED LIBERATION HD", 20.3223), ('QUAKE', 20.2616), ('KINGDOMS OF ENGLAND', 20.2051), ('HITMAN 2: SILENT ASSASSIN', 19.8991), ('ETERNIUM', 19.6592), ('KNIGHTS AND MERCHANTS', 19.5816), ('DATAJACK', 18.3469), ('STRONGHOLD 2: STEAM EDITION', 18.1877), ('XZR', 17.5362), ("ASSASSIN'S CREED", 17.4099), ("ASSASSIN'S CREED III", 17.2763), ('DRAGON HILLS', 17.2707), ('QUATTRO ADVENTURE', 17.1932), ('HALF-MINUTE HERO', 17.1505), ('WE ARE THE DWARVES', 17.0588), ('HYPER KNIGHTS', 16.9411), ('SHADOWLINGS', 16.8829), ('DRAGON ISLES', 16.7901), ('INTRAVENOUS', 16.5936), ('MR. SHIFTY', 16.5631), ('RESOLUTIION', 16.5325), ('QUEST OF DUNGEONS', 16.52), ('CHESS KNIGHTS: SHINOBI', 16.4116), ('SEVEN: ENHANCED EDITION', 16.3917), ("KING ARTHUR: KNIGHT'S TALE", 16.2674), ('NOCTURNE', 16.1967), ('VENGEANCE OF EXCALIBUR', 16.1803), ('IRON CRYPTICLE', 16.1437), ('BRIDGE CONSTRUCTOR: MEDIEVAL', 15.8003), ('STONE SLING', 15.5539), ("KING ARTHUR'S K.O.R.T.", 15.4908), ('MARCH OF EMPIRES: WAR OF LORDS', 15.4397), ("KING'S BOUNTY: NUSUMARETA CHITSUJO", 15.2579), ("KING'S BOUNTY", 15.2348), ("CASTLEVANIA II: BELMONT'S REVENGE", 15.1898), ('BELLRINGER III', 15.1776), ('RETRO CLASSIX: GATE OF DOOM', 15.0973), ('THE MISADVENTURE OF THE HOLY GRAIL', 15.0627), ('BLADE SYMPHONY', 15.0147), ('STYX: SHARDS OF DARKNESS', 14.9753), ('TENCHU: TIME OF THE ASSASSINS', 14.9646), ('CASTLES', 14.9521), ('ARAGAMI', 14.9315), ('ULTRA STREET FIGHTER IV', 14.9205), ("ASSASSIN'S CREED: REVELATIONS: COLLECTORS EDITION", 14.9056), ('HITMAN 2', 14.8692), ('DARK MESSIAH: MIGHT AND MAGIC', 14.8676), ('NOX ARCHAIST', 14.8377), ('RETRO CLASSIX: WIZARD FIRE', 14.7643), ('MURDEROUS PURSUITS', 14.7548), ('BLACK SQUAD', 14.7471), ('TRINE ENCHANTED EDITION', 14.736), ('NANOUI', 14.7311), ('DREAM OF MIRROR ONLINE', 14.7177), ('BROADSWORD : AGE OF CHIVALRY', 14.712), ('CHIVALRY 2', 14.704), ('CHIVALRY: MEDIEVAL WARFARE', 14.6957), ('RAMPAGE KNIGHTS', 14.695), ('ALTITUDE', 14.667), ("ASSASSIN'S CREED III REMASTERED", 14.6656), ('JET SET KNIGHTS', 14.6311), ('PANZAR', 14.6297), ('DUNGEON DEFENDERS II', 14.5612), ('MOUNT & BLADE: WARBAND', 14.5501), ("ASSASSIN'S CREED BROTHERHOOD AND REVELATIONS: DOUBLE PACK", 14.5262), ('PAINKILLER: BLACK EDITION', 14.524), ('ROGUE COMPANY', 14.4785), ('MOUNT & BLADE', 14.445), ('MOUNT & BLADE: WITH FIRE & SWORD', 14.4344), ('PORTAL KNIGHTS', 14.4234), ('TOTAL WAR: WARHAMMER', 14.4095), ('SHREK THE THIRD', 14.4003), ('UNDEAD KNIGHTS', 14.3798), ('BLACK CLOVER: QUARTET KNIGHTS', 14.3762), ('RIVAL KNIGHTS', 14.3758), ('COUNTER-STRIKE', 14.3618), ('HUMAN: FALL FLAT', 14.3588), ('HELL WARDERS', 14.3572), ('FOR HONOR', 14.3401), ('ROYAL QUEST', 14.3326), ('SPARTAN', 14.3195), ('BLACK DESERT', 14.3113), ('WARCUBE', 14.2423), ('WHAT THE FORK', 14.2142), ('CUBIC CASTLES', 14.1592), ('ROOKS KEEP', 14.1471), ('CASTLE CRASHERS', 14.1345), ('MEDIEVAL ENGINEERS', 14.1239), ('SPIRAL KNIGHTS', 14.0834), ("ASSASSIN'S CREED CHRONICLES: CHINA", 13.9067), ('MADE MAN: CONFESSIONS OF THE FAMILY BLOOD', 13.8951), ('NUCLEAR DAWN', 13.8417), ("ASSASSIN'S CREED CHRONICLES: INDIA", 13.8369), ('MIDWINTER II: FLAMES OF FREEDOM', 13.812), ('DARKSBURG', 13.8103), ('DARKSIDERS GENESIS', 13.8051), ('ENTER THE GUNGEON', 13.7751), ('LABYRINTH', 13.7255), ('LAST EPOCH', 13.7064), ('WOLCEN: LORDS OF MAYHEM', 13.6899), ('HALO: SPARTAN STRIKE', 13.6751), ('HYPER JAM', 13.6546), ('HEAT SIGNATURE', 13.6513), ('GARRISON', 13.6409), ('8BITMMO', 13.6361), ('THE SURVIVALISTS', 13.6242), ('LARA CROFT AND THE TEMPLE OF OSIRIS', 13.6182), ('POSTAL REDUX', 13.5925), ("THE SWORDS OF DITTO: MORMO'S CURSE", 13.5753), ('SAS: ZOMBIE ASSAULT 4', 13.5715), ('SPECIAL FORCES', 13.5667), ('VERSUS SQUAD', 13.5559), ('IN SPACE WE BRAWL', 13.5348), ('DOOR KICKERS', 13.5302), ('THE ESCAPISTS', 13.5264), ('SYNTHETIK: LEGION RISING', 13.5155), ('SHINOBIDO 2: REVENGE OF ZEN', 13.4944), ('TOWER 57', 13.4926), ('RUNNING WITH RIFLES',  ...
#
# HOARD -> 25.266873260011234
# indie action casual singleplayer strategy fantasy multiplayer arcade top-down co-op dragons action strategy - abilities archers base carts castles co crops dragon drive extinction fantasy fiery fire game gasps gold hoard home income kidnapping kingdom knights limit map maps merchant modes mound mouth name number one op parameters particularities pile player players preying princess princesses pursuit ransom ransoms selections sorts speed stream target targets thieves thumbsticks time treasure user wake waste windmills
# ['direct a stream', 'maximise income', 'heal and upgrade one of four abilities', 'decorate hoard', 'fly and one']
#
# ROAD REDEMPTION -> 23.061376032894227
# indie action singleplayer adventure simulation multiplayer arcade funny shooter violent third person gore sports racing rogue-like rogue-lite local multiplayer local co-op 4 player local motorbike action racing vehicle simulation role-playing beat 'em up - action adventure assassin assassinations bike biker bounty cartel challenges character co combat configurations control counters country death dictator enemy experience fans fighting friends game gamepad gang gangs grabs head home journey kicks leader life loot members mode money motorcycle mph multimonitor multiplayer op path peace period piece pipe place player prize races racing rage redemption road robberies screen!- skill splitscreen street strikes support system territory time tons tree truce warfare way weapons weapons.- world years
# ['let out some road', 'work with your friends', 'upgrade your character', 'Earn money', 'claim this prize', 'feel right at home', 'Rack in the loot', 'have to drive through enemy', 'chase down the assassin']
#
# ASSASSIN BLUE -> 20.398141089807915
# action platform amount assassin assassinations attack boss buttons ceilings child combos conflict continues cut directory elements enemies fights fire game games government health hints hitman icons levels missions mode motives movement music pack past path platformer platforms player puzzle questions regime rush scene sequences shop soundtrack speed spikes stab stances switches sword targets time tokens vines walls way woman
# ['clear the path', 'break through defensive stances', 'fight using a sword', 'add music', 'control the hitman']

# %% [markdown]
# ## Test prompts
# * Notes: Needs hyper-specific adjectives to get right on the money with the suggestions - otherwise can get a little too off.

# %%
prompts = [
    "a pixel skateboarding game in a cyberpunk future",                  #recs: the ramp, jet set radio, cyberpunk 2077
    "a cute, relaxing, atmospheric farming rpg with animal characters",  #recs: stardew valley, night in the woods, a short hike
    "a physics-based shopping simulator in a 90s mall",                   #recs: goat simulator, retrowave, donut county
    # "a first-person goat skateboarding game"
    ]  

for p in prompts:
    print(f"----- {p} -----")
    print("")
    recommendFeatures(p)
    print("")
    print("")
# Out:
# ----- a pixel skateboarding game in a cyberpunk future -----
#
# [('SKATEBOARD JOUST', 14.851314018215888), ("BLACK FUTURE '88", 12.140778781467823), ('ZEPHYR', 12.136567061172428)]
# [('SKATEBOARD JOUST', 14.8513), ("BLACK FUTURE '88", 12.1408), ('ZEPHYR', 12.1366), ('THEDAWN', 12.105), ('SPACE TRADER: MERCHANT MARINE', 12.095), ('SIGNALIS', 12.095), ('CIRCUIT BREAKERS', 12.0908), ('CROSSCODE', 12.0702), ('TECHNOBABYLON', 12.0702), ('DEX', 12.0702), ('YUPPIE PSYCHO: EXECUTIVE EDITION', 12.0702), ('GIGA WRECKER', 12.0702), ('NOWHERE PROPHET', 12.0702), ('VEKTOR WARS', 12.0675), ('APSULOV: END OF GODS', 12.0495), ('VANQUISH', 12.0341), ('ARMED TO THE GEARS', 12.0226), ('UMURANGI GENERATION', 12.0165), ('BABEL', 12.0124), ('AZURE STRIKER GUNVOLT', 12.0111), ('UNENDING DUSK', 12.0111), ('LIBERATED', 12.0065), ('G STRING', 12.0037), ('HELL: A CYBERPUNK THRILLER', 12.0036), ('WETLANDS', 11.9964), ('MAX HEADROOM', 11.9927), ('PSYCHO-PASS: MANDATORY HAPPINESS', 11.981), ('SIN EPISODES: EMERGENCE', 11.9734), ('TACOMA', 11.9666), ('PAYLOAD', 11.9649), ('THE LONGEST JOURNEY', 11.9571), ('BARGON ATTACK', 11.9568), ('CULPA INNATA', 11.9436), ("SHADOWRUN: DRAGONFALL: DIRECTOR'S CUT", 11.9436), ('RETROWAVE', 11.9413), ('TESLA EFFECT: A TEX MURPHY ADVENTURE', 11.9148), ('TEX MURPHY: OVERSEER', 11.9143), ('DIVINATION', 11.9099), ('SENSE: A CYBERPUNK GHOST STORY', 11.9098), ('FIRST SAMURAI', 11.8988), ('TALES OF THE NEON SEA', 11.8929), ('DREAMFALL CHAPTERS: THE FINAL CUT', 11.8908), ('MARS: WAR LOGS', 11.8892), ('MESSIAH', 11.8892), ('MASTER REBOOT', 11.8883), ('THE CORRIDOR: ON BEHALF OF THE DEAD', 11.8785), ('DISJUNCTION', 11.8731), ('THE SUNDEW', 11.8731), ('DRY DROWNING', 11.8731), ('OBSERVER: SYSTEM REDUX', 11.8639), ('>OBSERVER', 11.8632), ('BURNING DAYLIGHT', 11.8583), ('VIRTUAVERSE', 11.8409), ('QUANTUM REPLICA', 11.8194), ('SLAVE ZERO', 11.8116), ('JACK MOVE', 11.8095), ('SUBSURFACE CIRCULAR', 11.7685), ('ALTERNATIVA', 11.7664), ('A BEWITCHING REVOLUTION', 11.7458), ('INTERPHASE', 11.7387), ('CHAOS OVERLORDS', 11.7112), ('DATAJACK', 11.7094), ('WAVE BREAK', 11.2695), ('OLLIOLLI WORLD', 11.2119), ('OLLIOLLI', 11.1915), ('OLLIOLLI2: WELCOME TO OLLIWOOD', 11.177), ('TRUE SKATE', 11.1302), ('CRAYOLA SCOOT', 11.1253), ('TECH DECK SKATEBOARDING', 11.0611), ('TRICKSHOT', 11.0253), ('SKATE CITY', 11.0251), ('POGOSTUCK: RAGE WITH YOUR FRIENDS', 11.0057), ('SKATE 3', 11.005), ('CHESS FOR KIDS', 10.9999), ('EVOLUTION SKATEBOARDING', 10.9518), ('SKATEBIRD', 10.8812), ('FOTONICA', 10.5549), ('FINAL FANTASY III', 10.554), ('NOITA', 10.5528), ('AEON DRIVE', 10.5528), ('FINAL FANTASY II', 10.5452), ('FINAL FANTASY V (2021)', 10.5379), ('CLADUN RETURNS: THIS IS SENGOKU!', 10.5073), ('ADVENTURES OF PIP', 10.5048), ("COUNTRYBALL: CATCH 'EM ALL!", 10.5019), ("RETRO GRANNY'S GARDEN", 10.5004), ('CHROMA SQUAD', 10.4845), ('MUSYNX', 10.4478), ('INMOST', 10.4473), ('INSPECTOR WAFFLES', 10.4359), ('SQUIDLIT', 10.4247), ('LIFE OF PIXEL', 10.3969), ('ZOLYX', 10.3737), ('AEGEAN VOYAGE', 10.3621), ('R-TYPES', 10.3535), ('TRONN', 10.3324), ('RADICAL RADIAL', 10.307), ("SHOOT 'EM UP DESTRUCTION SET 3", 10.2985), ('HORGIHUGH', 10.2829), ('HYSTERIA HOSPITAL: EMERGENCY WARD', 10.2567), ('SUPER METROID: JUSTIN BAILEY', 10.1228), ('11-PUZZLE', 9.9508), ('FNURR 2000', 9.8151), ('BLOOD ALLOY', 8.2301), ('CYBERBYKES: SHADOW RACER VR', 8.146), ('MILE HIGH TAXI', 8.1251), ('SWARMRIDERS', 8.12), ('SEVERED STEEL', 8.1189), ('ENYO ARCADE', 8.1123), ('SPECTRE', 8.1121), ('ULTRAKILL', 8.0993), ('CLIFF EMPIRE', 8.0907), ('LIVEWIRE', 8.0785), ('MDK 2', 8.0737), ('GAUNTLET', 8.0712), ('COSMICBREAK UNIVERSAL', 8.0705), ('HEAVY METAL MACHINES', 8.0686), ('ECHO', 8.064), ('MONOLITH', 8.0636), ('REMEMBER ME', 8.0631), ('GRIDIRON', 8.0589), ('THE DESOLATE HOPE', 8.0546), ('PIXEL GLADIATOR', 8.0533), ('VOID AND MEDDLER', 8.0528), ('NIKOPOL: SECRETS OF THE IMMORTALS', 8.0521), ('SEVEN: ENHANCED EDITION', 8.0516), ('TOKYO 42', 8.0516), ('2064: READ ONLY MEMORIES', 8.0479), ('TYR: CHAINS OF VALHALLA', 8.0451), ('BYTEPATH', 8.0433), ('I HAVE NO MOUTH, AND I MUST SCREAM', 8.0408), ('HACKNET', 8.0388), ('AXIOM VERGE', 8.0388), ('NYAN CAT: LOST IN SPACE', 8.0388), ('KAPIA',  ...
#
# SKATEBOARD JOUST -> 14.851314018215888
# action bonus chamber coins enemies future objective obstacles place player powers score shooting skateboard skateboarding sport stage waves
# ['dispose of your enemies']
#
# BLACK FUTURE '88 -> 12.140778781467823
# 2d pixel graphics sci-fi platformer difficult co-op great soundtrack side scroller 1980s rogue-like rogue-lite local co-op action roguelike cyberpunk action ' action colossal dash explodes future heart homicidal junkies owner punk shoot slash top tower traps version waves way
# ['reach the top', 'climb an always evolving procedural tower', 'upgrade yourself to survive the endless waves', 'kill its insane owner']
#
# ZEPHYR -> 12.136567061172428
# 3d shooter sci-fi combat old school fps racing futuristic 1990's cyberpunk robots aliens driving dark humor dystopian destruction vehicular combat combat racing racing shooter advantages battles cannon century choice cities combat corporation corporations cyberpunk disadvantages earth elements energy future galaxy game locations mankind maze missions one opponents person perspective pilot plot power premise races racing resources right rights set shields shooting space turret ups vehicles wastelands world worlds zephyr
# ['proceed through a set', 'win the races', 'shoot your opponents', 'settle and exploit worlds']
#
#
#
# ----- a cute, relaxing, atmospheric farming rpg with animal characters -----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [51], line 11
#       9 print(f"----- {p} -----")
#      10 print("")
# ---> 11 recommendFeatures(p)
#      12 print("")
#      13 print("")
#
# Cell In [49], line 4, in recommendFeatures(userPrompt)
#       2 def recommendFeatures(userPrompt):
#       3     # get the closest game
# ----> 4     closestGames, other = getClosestGames(userPrompt)
#       5     print(closestGames)
#       7     #show more debug info
#
# Cell In [48], line 40, in getClosestGames(txt, k)
#      38 dists = {}
#      39 for g in GAME_DATA:
# ---> 40     dists[g] = gameThemeDist(toks,GAME_DATA[g]["tags"]+GAME_DATA[g]["entities"])   #use the theme words (entities + tags)
#      41     # dists[g] = gameThemeDist(entities,GAME_DATA[g]["entities"])   #only use entities
#      42
#      43 #multiply by the tag matches
#    (...)
#      47
#      48 #add tf-idf scores where found
#      49 for g in dists:
#
# Cell In [48], line 8, in gameThemeDist(g1, g2)
#       6 def gameThemeDist(g1,g2):
#       7     # both game has a set of theme words of varying lengths
# ----> 8     d = cosine_similarity([GLOVE_DAT[w] for w in g1 if w in GLOVE_DAT],[GLOVE_DAT[w] for w in g2 if w in GLOVE_DAT if w in GLOVE_DAT])
#      10     #average the distance
#      11     # return sum([sum(x) for x in d])/(len(g1)*len(g2))
#      12
#      13     #return the average of the max for each word in g1
#      14     return sum([max(x) for x in d])
#
# File ~/Desktop/GIL_Lab/BMO/BMO_chatbot_prototype/bmo-venv/lib/python3.8/site-packages/sklearn/metrics/pairwise.py:1383, in cosine_similarity(X, Y, dense_output)
#    1381     Y_normalized = X_normalized
#    1382 else:
# -> 1383     Y_normalized = normalize(Y, copy=True)
#    1385 K = safe_sparse_dot(X_normalized, Y_normalized.T, dense_output=dense_output)
#    1387 return K
#
# File ~/Desktop/GIL_Lab/BMO/BMO_chatbot_prototype/bmo-venv/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:1820, in normalize(X, norm, axis, copy, return_norm)
#    1818     elif norm == "max":
#    1819         norms = np.max(abs(X), axis=1)
# -> 1820     norms = _handle_zeros_in_scale(norms, copy=False)
#    1821     X /= norms[:, np.newaxis]
#    1823 if axis == 0:
#
# File ~/Desktop/GIL_Lab/BMO/BMO_chatbot_prototype/bmo-venv/lib/python3.8/site-packages/sklearn/preprocessing/_data.py:103, in _handle_zeros_in_scale(scale, copy, constant_mask)
#      89 """Set scales of near constant features to 1.
#      90
#      91 The goal is to avoid division by very small or zero values.
#    (...)
#     100 construction.
#     101 """
#     102 # if we are fitting on 1D arrays, scale might be a scalar
# --> 103 if np.isscalar(scale):
#     104     if scale == 0.0:
#     105         scale = 1.0
#
# File ~/Desktop/GIL_Lab/BMO/BMO_chatbot_prototype/bmo-venv/lib/python3.8/site-packages/numpy/core/numeric.py:1949, in isscalar(element)
#    1873 @set_module('numpy')
#    1874 def isscalar(element):
#    1875     """
#    1876     Returns True if the type of `element` is a scalar type.
#    1877
#    (...)
#    1947
#    1948     """
# -> 1949     return (isinstance(element, generic)
#    1950             or type(element) in ScalarType
#    1951             or isinstance(element, numbers.Number))
#
# KeyboardInterrupt:

# %% [markdown]
# ## TEST AREA`

# %%
for gt in ["CASTLE CRASHERS", "HYPER LIGHT DRIFTER", "THIEF GOLD", "THE ELDER SCROLLS V: SKYRIM", "ELDEN RING", "KINGSWAY"]:
    print(gt)
    print(sentGame(gt))
    for f in GAME_DATA[gt]["features"]:
        print(f"- {f}")
    # print(GAME_DATA[gt]["features"])
    print("")
# Out:
# CASTLE CRASHERS
# action casual singleplayer adventure rpg 2d multiplayer cute arcade funny comedy co-op cartoony medieval online co-op local multiplayer hack and slash local co-op 4 player local beat 'em up action adventure role-playing beat 'em up adventure arcade award castles characters crashers friends hack hand hi kingdom princess res slash victory visuals way
# - defend your kingdom
# - smash your way to victory
# - play locally or online to save your princess
# - crash some castles
#
# HYPER LIGHT DRIFTER
# indie action singleplayer adventure rpg 2d atmospheric pixel graphics fantasy colorful exploration sci-fi difficult top-down great soundtrack action rpg hack and slash post-apocalyptic metroidvania souls-like action role-playing action adventure bit blood classics collectors designs disease drifter drifters echoes grander histories illness knowledge land lands mechanics past resonate rpg scale technologies treasure vein way world
# - quiet the vicious disease
#
# THIEF GOLD
# action singleplayer adventure atmospheric story rich fantasy exploration first-person horror dark medieval dark fantasy immersive sim 1990's stealth classic moddable steampunk cult classic immersive action adventure stealth addition amount areas arrows beggar blackjack bodies bombs bow bugfixes campaign challenges changes chasms combat company cross design difficulties difficulty disposal elements enemies equipment era extinguishes fantasy fire flash footsteps forces game gem goals gold ground guard guards head keys lack level levels line lockpicks master masters metropolis mines mission missions modifications moss nobles noisemaker noises objective objects opponents order organization parts paths people person place places plans player plot purpose range reissue requirements rope ropes shadows skills sounds spots stage stealth streets surfaces surfacing sword technology thief thieving time torches town training treasures trinkets type types undead version visibility water way ways work world
# - move their bodies
# - steal their keys
# - accomplish the objective
# - appropriate the treasures
# - avoid being heard ( different surfaces
# - allow the player
# - avoid being seen ( the level
# - include bugfixes
# - keep his head
# - enter forbidden places
# - provide new challenges
# - skip some of the harder areas
# - soften the sounds
# - sneak on guards
#
# THE ELDER SCROLLS V: SKYRIM
# action singleplayer adventure rpg atmospheric story rich fantasy first-person third person open world great soundtrack sandbox medieval character customization action rpg magic lore-rich moddable dragons epic action role-playing alliances balance claims conflict dragons edge elder evil future hero midst passages power prophesized throne v
# - stand amongst the dragons
# - comea hero
#
# ELDEN RING
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [26], line 3
#       1 for gt in ["CASTLE CRASHERS", "HYPER LIGHT DRIFTER", "THIEF GOLD", "THE ELDER SCROLLS V: SKYRIM", "ELDEN RING", "KINGSWAY"]:
#       2     print(gt)
# ----> 3     print(sentGame(gt))
#       4     for f in GAME_DATA[gt]["features"]:
#       5         print(f"- {f}")
#
# Cell In [22], line 3, in sentGame(g)
#       2 def sentGame(g):
# ----> 3     return " ".join(GAME_DATA[g]["tags"])+" "+" ".join(GAME_DATA[g]["entities"])
#
# KeyError: 'ELDEN RING'

# %%
GAME_DAT_TFIDF["CYBERPUNK 2077"]
# Out:
# {'character': 1.9661128563728327,
#  'rockerboy': 3.912023005428146,
#  'exploration': 1.3470736479666094,
#  'key': 3.912023005428146,
#  'futuristic': 2.8134107167600364,
#  'body': 3.912023005428146,
#  'players': 1.2039728043259361,
#  'open world': 1.4271163556401458,
#  'immersive sim': 2.8134107167600364,
#  'world': 0.8209805520698303,
#  'immortality': 3.912023005428146,
#  'corporation': 3.912023005428146,
#  'v': 2.8134107167600364,
#  'nudity': 3.2188758248682006,
#  'great soundtrack': 0.5108256237659907,
#  'first-person': 1.7147984280919266,
#  'mature': 3.2188758248682006,
#  'cyberware': 3.912023005428146,
#  'sci-fi': 1.8325814637483102,
#  'city': 2.120263536200091,
#  'modification': 3.912023005428146,
#  'story rich': 1.2039728043259361,
#  'characters': 1.6094379124341003,
#  'character customization': 2.302585092994046,
#  'cast': 2.8134107167600364,
#  'cyberpunk': 2.302585092994046,
#  'ability': 3.912023005428146,
#  'role': 3.2188758248682006,
#  'technology': 3.2188758248682006,
#  'action rpg': 1.9661128563728327,
#  'megalopolis': 3.912023005428146,
#  'choices': 2.8134107167600364,
#  'violent': 2.8134107167600364,
#  'story': 1.9661128563728327,
#  'prototype': 3.2188758248682006,
#  'fps': 2.8134107167600364}

# %%
# show the distances between the word sets as a table
def showSim(arr2d,x,y):
    # print the table
    z = "X"
    print(f"{z.ljust(10)}",end="")
    for i in x:
        print(f"{i[:8].ljust(10)}",end="")
    print("")
    for i in range(len(arr2d)):
        print(f"{y[i][:8].ljust(10):10}",end="")
        for j in range(len(arr2d[i])):
            print(f"{str(arr2d[i][j]).ljust(10)}",end="")
        print("")


# tokenize and remove all stop words
entities = ["knights", "castle", "assassination"]
ideal_games = ["CASTLE CRASHERS", "HAMMERWATCH", "THIEF GOLD", "THE ELDER SCROLLS V: SKYRIM", "ELDEN RING", "KINGSWAY"]
# actual_games = ["DOWNWELL", "VAMPIRE SURVIVORS", "BATMAN: ARKHAM CITY"]
actual_games = ["MINI NINJAS", "THE BINDING OF ISAAC", "NIDHOGG"]

# get the closest games using distance metrics
i_dists = {}
i_break = {}
for g in ideal_games:
    i_dists[g] = gameThemeDist(entities,GAME_DATA[g]["entities"])   #only use entities
    i_break[g] = []  
    for i in entities:
        a = []
        for j in GAME_DATA[g]["entities"]:
            if i in GLOVE_DAT and j in GLOVE_DAT:
                a.append(cosine_similarity([GLOVE_DAT[i]],[GLOVE_DAT[j]])[0][0]*GAME_DAT_TFIDF[g][j])
            else:
                a.append(0)
        a.append(np.max(a))
        i_break[g].append(a)
            
    # i_break[g] = cosine_similarity([GLOVE_DAT[w] for w in entities if w in GLOVE_DAT],[GLOVE_DAT[w] for w in GAME_DATA[g]["entities"] if w in GLOVE_DAT if w in GLOVE_DAT])

a_dists = {}
a_break = {}
for g in actual_games:
    a_dists[g] = gameThemeDist(entities,GAME_DATA[g]["entities"])   #only use entities
    a_break[g] = []  
    for i in entities:
        a = []
        for j in GAME_DATA[g]["entities"]:
            if i in GLOVE_DAT and j in GLOVE_DAT:
                a.append(cosine_similarity([GLOVE_DAT[i]],[GLOVE_DAT[j]])[0][0]*GAME_DAT_TFIDF[g][j])
            else:
                a.append(0)
        a.append(np.max(a))
        a_break[g].append(a)

    # a_break[g] = cosine_similarity([GLOVE_DAT[w] for w in entities if w in GLOVE_DAT],[GLOVE_DAT[w] for w in GAME_DATA[g]["entities"] if w in GLOVE_DAT if w in GLOVE_DAT])


#show distances
print(entities)
print("")

print("\nIDEAL GAMES")
for g in i_dists:
    print(f"{g} -> {i_dists[g]}")
    x = GAME_DATA[g]["entities"] + ["MAX"]
    showSim(np.around(i_break[g],4),x,entities)
    print("")
    # print(i_dists[g])
    # print(np.around(i_break[g],2))
    # print("")

print("\nACTUAL GAMES")
for g in a_dists:
    print(f"{g} -> {a_dists[g]}")
    x = GAME_DATA[g]["entities"] + ["MAX"]
    showSim(np.around(a_break[g],4),x,entities)
    print("")
    # print(a_dists[g])
    # print(np.around(a_break[g],2))
    # print("")
# Out:
# ['knights', 'castle', 'assassination']
#
#
# IDEAL GAMES
# CASTLE CRASHERS -> 1.4532353806595277
# X         adventur  arcade    award     castles   characte  crashers  friends   hack      hand      hi        kingdom   princess  res       slash     victory   visuals   way       MAX
# knights   0.2184    0.7287    1.0496    1.8414    0.4665    0.0716    0.475     -0.0219   0.3712    -0.1035   1.7534    0.9923    -0.5047   -0.0834   1.3338    -0.2149   0.2118    1.8414
# castle    0.2242    0.8608    0.3959    2.7652    0.494     0.686     0.5149    -0.1383   0.5172    -0.173    2.0129    1.8139    -0.8778   -0.5066   0.8286    -0.004    0.3824    2.7652
# assassin  0.1358    0.0138    0.5769    -0.2865   0.3647    0.3698    0.4884    0.1759    0.6348    -0.7147   0.995     0.8659    0.1804    -0.1924   1.0482    -0.2528   0.3202    1.0482
#
# HAMMERWATCH -> 1.2761834602584552
# X         -         action    adventur  art       bottom    classes   co        customiz  developm  difficul  editing   enemies   environm  environm  fantasy   features  gamepads  hack      hordes    levels    liking    looks     medium    modifier  online    op        players   puzzles   secrets   skills-   solo      support   things    top       traps     unlocks   MAX
# knights   0.08      0.122     0.2184    0.7617    0.8831    1.1039    0.2091    0.1557    -0.0219   -0.0838   -0.4331   0.8711    -0.3357   0.0578    0.6848    0.4716    0.0       -0.0219   1.0776    0.0819    -0.1627   0.1613    0.2751    0.0       0.0979    -0.2961   0.4515    -0.0519   0.2772    0.0       0.4971    0.5667    0.2492    0.6835    0.042     0.0561    1.1039
# castle    0.1403    0.0837    0.2242    0.9629    1.2268    0.4801    0.3464    -0.02     0.6616    0.1381    0.253     0.5272    0.2289    0.5007    0.519     1.0437    0.0       -0.1383   0.4934    0.0579    0.0449    1.0976    0.4323    0.0       0.2164    0.4381    0.1192    0.1769    0.2625    0.0       0.2157    0.4543    0.6424    0.4331    0.3621    0.0017    1.2268
# assassin  0.6517    0.2785    0.1358    0.2597    -0.2529   0.0683    0.7486    -1.1577   0.7913    0.467     0.244     1.1411    0.3064    -0.5497   0.3567    0.1914    0.0       0.1759    0.1123    0.1554    -0.3141   0.4752    -0.4596   0.0       0.2055    0.0836    0.0462    0.0389    0.6723    0.0       0.1284    1.2749    0.6058    0.6967    0.6033    -0.3765   1.2749
#
# THIEF GOLD -> 1.9361881213418777
# X         addition  amount    areas     arrows    beggar    blackjac  bodies    bombs     bow       bugfixes  campaign  challeng  changes   chasms    combat    company   cross     design    difficul  difficul  disposal  elements  enemies   equipmen  era       extingui  fantasy   fire      flash     footstep  forces    game      gem       goals     gold      ground    guard     guards    head      keys      lack      level     levels    line      lockpick  master    masters   metropol  mines     mission   missions  modifica  moss      nobles    noisemak  noises    objectiv  objects   opponent  order     organiza  parts     paths     people    person    place     places    plans     player    plot      purpose   range     reissue   requirem  rope      ropes     shadows   skills    sounds    spots     stage     stealth   streets   surfaces  surfacin  sword     technolo  thief     thieving  time      torches   town      training  treasure  trinkets  type      types     undead    version   visibili  water     way       ways      work      world     MAX
# knights   0.7712    0.002     0.2313    1.4089    0.3996    1.0233    0.4746    0.1033    1.0375    -0.7734   0.2106    0.1634    0.2361    0.5458    0.5494    0.466     1.1303    0.3866    0.0653    -0.0838   0.0491    0.6398    0.8711    0.0136    0.7639    -0.4578   0.6848    0.7514    0.016     1.1238    1.3775    0.2055    0.8303    0.5863    1.2301    0.8113    1.5631    1.598     0.6535    0.8094    0.2097    0.5172    0.0819    0.751     0.0       1.2089    1.4584    0.2896    0.2541    0.5524    0.7938    0.0776    0.2999    2.4205    -0.9058   -0.4993   0.1037    0.7556    0.9       0.8654    0.531     0.4129    0.2755    0.3464    0.1516    0.9797    1.1585    0.1597    0.4981    0.3477    0.5903    0.5671    0.1916    0.0317    0.3834    0.9127    1.2939    0.5483    0.0754    0.3514    0.8759    0.2569    0.6432    -0.1288   -0.5933   2.04      -0.0394   1.0629    0.3993    0.3361    0.1533    0.797     1.0409    0.8596    0.3585    0.6722    0.4177    1.6296    0.2375    -0.4335   0.0328    0.2118    0.135     0.5347    0.2325    2.4205
# castle    1.0822    0.3723    0.891     0.1654    0.6137    0.5144    0.4378    0.6547    1.0024    -0.7692   0.3188    0.2194    0.6414    -0.112    0.0038    0.9419    1.007     1.0119    0.6021    0.1381    0.7117    0.5896    0.5272    0.2756    0.5118    -0.7503   0.519     1.0764    0.3898    0.7797    1.0884    0.1075    0.838     -0.0792   0.8395    1.2689    0.5567    0.794     0.6647    0.9087    0.3444    0.4443    0.0579    1.2339    0.0       0.9623    0.9027    0.8847    0.9265    0.7029    0.2655    0.6964    0.7936    1.4549    -0.9575   -0.2485   0.2932    0.8773    -0.0017   0.7321    -0.2913   1.502     0.6674    0.4592    0.3727    1.4203    1.7249    0.9564    0.2189    1.3751    0.6992    0.8537    0.1652    0.0174    0.4338    0.404     1.1104    0.0268    0.5029    0.4789    1.338     -0.4785   1.1849    0.5375    -0.6367   1.2495    0.1709    0.8187    -0.6399   0.4037    -0.5769   1.7885    0.4047    0.9892    0.3284    0.8594    0.3817    0.9326    0.7146    -0.3741   0.9684    0.3824    0.3487    1.0068    0.1564    1.7885
# assassin  0.7928    0.2515    0.3592    0.3356    -0.0127   -0.6334   1.0801    1.8156    0.4713    -0.7661   1.4192    0.911     1.0374    -0.4195   0.7325    0.3195    0.7354    0.3143    1.1577    0.467     0.7215    0.7721    1.1411    0.127     0.7514    -0.4971   0.3567    1.4144    0.8509    0.8925    1.8256    0.0755    -0.4395   0.472     0.0027    0.5127    0.9781    1.1996    0.9354    -0.091    0.8611    0.28      0.1554    0.5285    0.0       0.4954    0.1228    0.2803    0.6683    1.1007    0.8342    0.4505    -0.2686   0.3531    -0.2188   0.1093    0.7725    0.4754    1.6069    0.7023    0.8493    0.5168    0.1594    0.8982    0.5642    0.777     0.6823    1.2431    0.0486    2.1945    0.8483    -0.0091   -0.1461   0.0368    -0.2518   -0.5986   0.7849    0.0074    -0.0689   0.1373    1.2199    0.5234    0.7534    -0.6384   0.2041    0.8485    0.2616    1.0344    -0.3708   0.3873    0.5647    0.7406    0.6076    0.2887    -0.3087   0.4748    0.0992    0.6586    0.5032    -0.264    -0.0521   0.3202    0.7794    1.0223    0.1818    2.1945
#
# THE ELDER SCROLLS V: SKYRIM -> 1.5933729595361972
# X         alliance  balance   claims    conflict  dragons   edge      elder     evil      future    hero      midst     passages  power     prophesi  throne    v         MAX
# knights   0.7316    0.1855    0.4068    0.4805    2.3361    0.7725    1.2325    1.5654    0.7331    1.1661    0.5582    -0.2199   0.5944    -0.5424   1.4935    1.009     2.3361
# castle    -0.0687   0.1532    0.6684    0.6315    0.9833    1.159     1.4067    1.0602    0.9005    0.7969    0.7738    0.7257    0.6656    -0.3893   1.6299    1.052     1.6299
# assassin  0.4703    0.2396    1.667     1.5768    -0.0371   0.0363    1.5789    1.7457    1.2281    1.3058    1.5984    0.2566    1.0481    -0.0576   1.0374    0.1325    1.7457
#
# ELDEN RING -> 1.2481985621348697
# X         action    collabor  fantasy   game      material  novelist  ring      ring[a    role      setting   MAX
# knights   0.122     0.4443    0.6848    0.2055    -0.0313   0.0191    1.5752    0.0       0.7336    0.6757    1.5752
# castle    0.0837    0.2618    0.519     0.1075    0.6796    0.4208    1.384     0.0       0.8192    1.2077    1.384
# assassin  0.2785    0.9264    0.3567    0.0755    0.7462    1.0833    1.025     0.0       1.5829    1.3164    1.5829
#
# KINGSWAY -> 1.6853223924256446
# X         adventur  adventur  backpack  bandits   caves     characte  crypts    death     element   emails    enemies   file      folders   game      interfac  items     land      mock      monsters  operatin  part      play      popups    quests    rpg       skills    style     system    time      top       traps     treasure  types     way       world     MAX
# knights   0.2184    1.7443    -0.0966   1.5092    0.6512    0.4775    0.7076    0.7506    0.6209    -0.5096   0.8711    0.1515    -0.1462   0.2055    -0.3089   0.0583    0.8082    0.9572    1.034     0.3478    1.2956    1.0629    -0.9269   1.0956    0.2149    0.5483    0.5499    0.3027    0.3361    0.6835    0.042     1.151     0.4177    0.2118    0.2325    1.7443
# castle    0.2242    0.4966    -0.4597   0.1359    1.2119    0.6912    0.7713    0.9295    0.7771    -0.7055   0.5272    0.2674    -0.3782   0.1075    0.2947    0.3415    1.4779    0.5777    0.5389    0.5926    1.9693    0.7653    -1.6546   0.4313    -0.0687   0.0268    0.7594    0.4412    0.4037    0.4331    0.3621    1.2253    0.3817    0.3824    0.1564    1.9693
# assassin  0.1358    -0.175    0.0791    1.1368    0.2905    0.6436    -0.4704   2.1642    1.0059    0.0201    1.1411    0.3376    -0.7645   0.0755    -0.2368   0.1752    0.5482    1.527     0.3654    0.43      1.294     0.3585    -1.1456   0.0522    0.2752    0.0074    0.3398    0.3591    0.3873    0.6967    0.6033    0.4001    0.0992    0.3202    0.1818    2.1642
#
#
# ACTUAL GAMES
# MINI NINJAS -> 1.602974163414483
# X         amount    animals   army      arrow     balance   characte  choice    directio  disciple  earthqua  environm  freedom   friend    hint      master    minions   nature    ninjas    none      objectiv  order     person    perspect  players   samurai   storms    transfor  warlord   warriors  world     worlds    MAX
# knights   0.002     0.6134    1.6408    1.3047    0.1855    0.4665    0.2422    0.4524    1.5615    0.4302    -0.3357   0.5792    0.4578    0.1292    1.2089    1.4612    0.5035    1.7035    0.6376    0.1037    0.8654    0.1516    0.3024    0.4515    2.3595    0.0567    0.3397    0.6681    2.4653    0.2325    0.8534    2.4653
# castle    0.3723    0.5337    1.3018    0.7246    0.1532    0.494     0.5236    0.9611    0.7041    0.3166    0.2289    0.0662    0.9764    0.498     0.9623    0.6157    0.8773    -0.1161   0.7582    0.2932    0.7321    0.3727    0.2176    0.1192    0.5996    0.1401    0.8432    0.5613    0.794     0.1564    0.5173    1.3018
# assassin  0.2515    0.2254    1.7114    0.5324    0.2396    0.3647    0.7529    0.5908    1.1259    0.5991    0.3064    0.7705    1.1676    0.546     0.4954    0.7316    0.7834    0.1265    1.3844    0.7725    0.7023    0.5642    0.2819    0.0462    0.4733    0.483     1.2951    1.924     0.4576    0.1818    0.2606    1.924
#
# THE BINDING OF ISAAC -> 1.4354307648022324
# X         abilitie  action    basement  binding   brothers  creature  droves    elements  enemies   faith     fears     form      isaac     journey   mother    players   sacrific  safety    secrets   sisters   treasure  voice     way       MAX
# knights   0.7448    0.122     0.6091    -0.2573   1.8125    0.9278    0.1475    0.6398    0.8711    1.2137    0.3222    0.9293    0.8615    0.307     0.3414    0.4515    0.9384    0.0743    0.2772    1.4788    0.8596    0.1198    0.2118    1.8125
# castle    0.0071    0.0837    1.8642    -0.2084   1.355     0.5734    0.132     0.5896    0.5272    0.5166    0.4332    1.1245    1.1005    0.7963    0.9436    0.1192    -0.1061   -0.1161   0.2625    1.0096    0.9892    0.3094    0.3824    1.8642
# assassin  0.3166    0.2785    0.2609    0.599     1.4294    0.2711    0.0691    0.7721    1.1411    0.9325    1.6974    0.6488    0.8923    0.7221    0.956     0.0462    0.6105    0.7274    0.6723    0.3104    0.2887    0.371     0.3202    1.6974
#
# NIDHOGG -> 1.5037352257380863
# X         end       environm  fighting  game      jump      opponent  player    players   respawns  screen    seconds   side      slide     swords    wins      MAX
# knights   0.6018    -0.3357   1.0806    0.2055    0.3444    0.4733    0.4981    0.4515    0.0       0.3055    -0.1001   0.7259    0.1544    2.2168    0.8683    2.2168
# castle    0.8022    0.2289    0.6791    0.1075    -0.0619   0.219     0.2189    0.1192    0.0       0.5996    -0.1513   1.0003    0.362     1.0256    0.1659    1.0256
# assassin  0.7551    0.3064    1.8202    0.0755    0.1513    0.918     0.0486    0.0462    0.0       0.2934    0.3579    0.3043    0.3086    0.1683    0.6802    1.8202

# %%
# Out:
# 44
