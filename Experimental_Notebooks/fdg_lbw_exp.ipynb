# %% [markdown]
# # FDG Late-Breaking Work Experiment Section
# Uses the two AI generations and human-made (extracted from Steam descriptions) text as comparison for real and fake games to ask users which set they prefer

# %% [markdown]
# #### IMPORTS AND SETUP

# %%
import os
import torch
import random
from tqdm import tqdm

# other files
import sys
sys.path.append('../')
import Python.utils as utils
import Python.GAME_FEATURE_REC_MOD as gfr_mod

# %%
# setup the game recommender
GRMOD = gfr_mod.GameRecMod()
GRMOD.setup()
# Out:
# Importing full game data...
# Importing GloVe: 100%|██████████| 400000/400000 [00:05<00:00, 66821.02it/s]

# %%
# import the transformer model
from transformers import GPT2LMHeadModel, GPT2Tokenizer

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

import_model_path = "../models/transformers/feature_generator"
model_name = "gpt2"

feat_tokenizer = GPT2Tokenizer.from_pretrained(model_name, bos_token='<|startoftext|>',eos_token='<|endoftext|>', pad_token='<|pad|>')
feat_gen_model = GPT2LMHeadModel.from_pretrained(import_model_path).to(DEVICE)
feat_gen_model.resize_token_embeddings(len(feat_tokenizer))
_ = feat_gen_model.eval()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %% [markdown]
# #### PREDICTION CODE

# %%
def getEntTags(prompt,shuffle=False):
    #remove all stop words
    tokens = utils.tokenize(prompt)

    #separate for the tags and entities
    tags = [t for t in tokens if t in GRMOD.ALL_TAGS]
    entities = [e for e in tokens if not e in tags]

    if shuffle:
        random.shuffle(tags)
        random.shuffle(entities)
    return tags, entities

# %%
# for the transformer generator

# predict features from a transformer model given a prompt
def predictTrans(prompt, args={}):
    tags, entities = getEntTags(prompt,shuffle=True)
    tag_str = ",".join(tags)
    entity_str = ",".join(entities)
    input_txt = f"<|startoftext|>{tag_str}\n{entity_str}\n-"
    generated = feat_tokenizer(input_txt, return_tensors="pt").input_ids.to(DEVICE)

    # perform prediction
    MAX_LEN = 512
    top_k = args['top_k'] if 'top_k' in args else 50
    top_p = args['top_p'] if 'top_p' in args else 1.0
    temperature = args['temperature'] if 'temperature' in args else 0.9
    repetition_penalty = args['rep_pen'] if 'rep_pen' in args else 0.95
    
    print(f"k {top_k}, p: {top_p}, temp: {temperature}")
    
    sample_outputs = feat_gen_model.generate(generated, do_sample=True, top_k=top_k, max_length=512, top_p=top_p, temperature=temperature, repetition_penalty = repetition_penalty, pad_token_id=feat_tokenizer.convert_tokens_to_ids('<|pad|>'))

    # decode the predicted tokens into texts
    pred_text = feat_tokenizer.decode(sample_outputs[0], skip_special_tokens=True)

    # print/return the predicted text
    # print(pred_text)
    return pred_text

# predict features from a transformer model given a set of tokens
def predictTrans2(tags, entities, args={}):
    tag_str = ",".join(tags)
    entity_str = ",".join(entities)
    input_txt = f"<|startoftext|>{tag_str}\n{entity_str}\n-"
    generated = feat_tokenizer(input_txt, return_tensors="pt").input_ids.to(DEVICE)

    # perform prediction
    MAX_LEN = 512
    top_k = args['top_k'] if 'top_k' in args else 50
    top_p = args['top_p'] if 'top_p' in args else 1.0
    temperature = args['temperature'] if 'temperature' in args else 0.9
    repetition_penalty = args['rep_pen'] if 'rep_pen' in args else 0.95
    # repetition_penalty = args['rep_pen'] if 'rep_pen' in args else 0.05

    
    print(f"k {top_k}, p: {top_p}, temp: {temperature}")
    
    sample_outputs = feat_gen_model.generate(generated, do_sample=True, top_k=top_k, max_length=512, top_p=top_p, temperature=temperature, repetition_penalty = repetition_penalty, pad_token_id=feat_tokenizer.convert_tokens_to_ids('<|pad|>'))

    # decode the predicted tokens into texts
    pred_text = feat_tokenizer.decode(sample_outputs[0], skip_special_tokens=True)

    # print/return the predicted text
    # print(pred_text)
    return pred_text


# for the concept net generator
def predictConNet(prompt):
    tags, entities = getEntTags(prompt)
    tokens = tags + entities

    # set up the feature recommender
    FMOD = gfr_mod.FeatureMod(tokens,get_related=False)
    return [f"- {f}" for f in FMOD.generate(15)], FMOD

def predictConNet2(tokens):
    # set up the feature recommender
    FMOD = gfr_mod.FeatureMod(tokens,get_related=False)
    return [f"- {f}" for f in FMOD.generate(15)], FMOD

# %% [markdown]
# #### PROMPTS AND GAME SELECTION

# %%
# get the human authored game features from real games pulled from Steam
real_games = [
    {
        "name": "TEAM FORTRESS 2",
        "prompt": "a class based multiplayer online shooter with a variety of modes including capture the flag, death match, and deliver the payload",
        "tags": [],
        "entities": [],
        "human_features": ["- shoot gun to heal allies", "- double jump in the air", "- drink energy drinks", "- throw suspicious jars", "- backstab enemy targets", "- sneak across terrain"]
    },
    {
        "name": "DOTA 2",
        "prompt": "a 5v5 game where you protect your base while destroying enemy bases using an array of different abilities and items",
        "tags": [],
        "entities": [],
        "human_features": ["- kill npc enemies", "- buy power ups", "- type to communicate with enemy team", "- coordinate tactics with allies", "- protect allied mobs", "- attack enemy turrets"]
    },
    {
        "name": 'THE LEGEND OF ZELDA: BREATH OF THE WILD',
        "prompt": "an open-world exploration game in a post-apocalyptic fantasy world where you can climb anything and destroy everything",
        "tags": [],
        "entities": [],
        "human_features": ["- explore the wilds", "- battle towering enemies", "- think quickly and develop the right strategies", "- gather ingredients", "- earn special items", "- bundle up with warmer clothes"]
    }
]

# get the human authored game features from fake games
fake_games = [
    {
        "name": "ALCHEMY PRINCESS",
        "prompt": "an RPG about a princess who collects swords and flowers to turn into potions and is secretly a frog",
        "tags": [],
        "entities": [],
        "human_features": ["- fight sludge monsters in the swamp", "- discover new alchemy recipes", "- identify new flora and fauna", "- explore the ruined castle", "meet new animal friends", "find the antidote to your curse"]
    },
    {
        "name": "THE ONIGIRI DORM",
        "prompt": "a collaborative cooking game where you make and sell onigiri in your college dorm room",
        "tags": [],
        "entities": [],
        "human_features": ["- make onigiri on the weekends", "- set your own prices", "- buy new meats and veggies", "- decorate your dorm room", "- pay off your tuition", "- hire friends and roommates part-time"]
    },
    {
        "name": "HOVERDECK 209X",
        "prompt": "a retro-futuristic cyberpunk skateboarding game where you hack corporations, the robot police, and the street gangs",
        "tags": [],
        "entities": [],
        "human_features": ["- hack the corpo suits", "- vandalize properties with graffiti", "- find secret hideouts", "- race the street gangs", "- upgrade your bioware tech", "- skate the streets of the city"]
    }
]

# %%
for game in real_games:
    t = GRMOD.getGameTags(game['name'])
    e = GRMOD.getGameEntities(game['name'])
    game['tags'] = t
    game['entities'] = e

# set the entities and tags for each fake game
# fake_game_rec_set = [['ARCUS SPIRITS'], ['QUIZ TORIMONOCHOU'], ['WAVE BREAK']]
# fake_game_rec_set = [['ARCUS SPIRITS', 'SCHOOL RUMBLE', 'TRIPLE SCORE: 3 GAMES IN 1'], ['QUIZ TORIMONOCHOU', 'KEN TO MAHOU TO GAKUEN MONO. FINAL: SHINNYUSEI WA OHIMESAMA', 'ALESHAR: THE WORLD OF ICE'], ['WAVE BREAK', 'OLLIOLLI WORLD', 'SKATE 3']]

fake_game_rec_set = [["ALCHEMY GARDEN"], ["OVERCOOKED"], ['OLLIOLLI WORLD']]
for g in range(len(fake_game_rec_set)):
    t = []
    e = []
    for game in fake_game_rec_set[g]:
        t += GRMOD.getGameTags(game)
        e += GRMOD.getGameEntities(game)
    fake_games[g]['tags'] = t
    fake_games[g]['entities'] = e

# %% [markdown]
# #### MAKE NEW FEATURES

# %%
# get the transformer features for all of the games
for game in real_games:
    print(f"Getting features for {game['name']}")
    p = 0.8
    k = 100
    t = 0.99
    arg_set = {'top_k':k,'top_p':p, 'temperature':t}
    game['trans_features'] = predictTrans2(game['tags'], game['entities'], arg_set).split("\n")

for game in fake_games:
    print(f"Getting features for {game['name']}")
    p = 0.8
    k = 100
    t = 0.99
    arg_set = {'top_k':k,'top_p':p, 'temperature':t}
    ptok = getEntTags(game['prompt'])
    game['trans_features'] = predictTrans2(game['tags']+ptok[0], game['entities']+ptok[1], arg_set).split("\n")
# Out:
# Getting features for TEAM FORTRESS 2
# k 100, p: 0.8, temp: 0.99
# Getting features for DOTA 2
# k 100, p: 0.8, temp: 0.99
# Getting features for THE LEGEND OF ZELDA: BREATH OF THE WILD
# k 100, p: 0.8, temp: 0.99
# Getting features for ALCHEMY PRINCESS
# k 100, p: 0.8, temp: 0.99
# Getting features for THE ONIGIRI DORM
# k 100, p: 0.8, temp: 0.99
# Getting features for HOVERDECK 209X
# k 100, p: 0.8, temp: 0.99

# %%
# get the feature generator features for all of the games
for game in tqdm(real_games):
    cnf, cnm = predictConNet2(game['entities'])
    game['cnet'] = cnm
    game['cnet_features'] = cnf

for game in tqdm(fake_games):
    tokens = utils.tokenize(game['prompt'])
    cnf, cnm = predictConNet2(game['entities']+tokens)
    game['cnet'] = cnm
    game['cnet_features'] = cnf
# Out:
# Getting related features: 100%|██████████| 78/78 [00:12<00:00,  6.24it/s]
# Getting related features: 100%|██████████| 33/33 [00:05<00:00,  6.27it/s]
# Getting related features: 100%|██████████| 59/59 [00:09<00:00,  6.45it/s]
# 100%|██████████| 3/3 [00:29<00:00,  9.95s/it]
# Getting related features: 100%|██████████| 47/47 [00:07<00:00,  6.21it/s]
# Getting related features: 100%|██████████| 74/74 [00:12<00:00,  6.11it/s]
# Getting related features: 100%|██████████| 81/81 [00:12<00:00,  6.24it/s]
# 100%|██████████| 3/3 [00:36<00:00, 12.27s/it]

# %% [markdown]
# #### Print the results

# %%
def fprint(txt,reset=False):
    print(txt)
    if reset:
        with open("../data/feature_comp.txt", "w") as f:
            f.write(txt + "\n")
    else:
        with open("../data/feature_comp.txt", "a") as f:
            f.write(txt + "\n")

fprint("====== FEATURE COMPARISON ======\n\n",reset=True)

nl = "\n"
for game in real_games:
    fprint(f"Game: {game['name']}")
    fprint(f"Prompt: {game['prompt']}")

    hf = "\n".join(game['human_features'])
    tf = "\n".join(game['trans_features'])
    cf = "\n".join(game['cnet_features'])

    fprint(f"-- Human Features -- {nl}{hf}{nl}")
    fprint(f"-- Transformer Features -- {nl}{tf}{nl}")
    fprint(f"-- ConceptNet Features -- {nl}{cf}{nl}")

for game in fake_games:
    fprint(f"Game: {game['name']}")
    fprint(f"Prompt: {game['prompt']}")

    hf = "\n".join(game['human_features'])
    tf = "\n".join(game['trans_features'])
    cf = "\n".join(game['cnet_features'])

    fprint(f"-- Human Features -- {nl}{hf}{nl}")
    fprint(f"-- Transformer Features -- {nl}{tf}{nl}")
    fprint(f"-- ConceptNet Features -- {nl}{cf}{nl}")
# Out:
# ====== FEATURE COMPARISON ======
#
#
# Game: TEAM FORTRESS 2
# Prompt: a class based multiplayer online shooter with a variety of modes including capture the flag, death match, and deliver the payload
# -- Human Features --
# - shoot gun to heal allies
# - double jump in the air
# - drink energy drinks
# - throw suspicious jars
# - backstab enemy targets
# - sneak across terrain
#
# -- Transformer Features --
# action,free to play,multiplayer,first-person,funny,shooter,comedy,co-op,fps,cartoony,online co-op,tactical,crafting,cartoon,robots,team-based,competitive,class-based,hero shooter,trading,action,shooter
# -,abilities,achievements,activity,assault,attempt,background,base,beam,bercharge,bomb,bunch,cart,cell,chain,checkpoints,class,classes,classics,commentary,control,defense,developer,elements,end,enemy,example,feature,game,gameplay,games,gun,healing,instant,kart,kills,loner,look,map,maps,medic,melee,menu,mini,mode,modes,multiplayer,offensive,order,overview,past,payload,player,points,rail,release,remake,round,route,school,seconds,series,set,shooter,signature,spy,statistics,stats,style,successor,targets,team,teams,time,type,use,version,weapons
# - access all the stats
# - play all the way
# - change the look
# - earn experience
# - gain points
# - use all these classes
# - access all the stats
# - use a bomb
# - access all the stats
# - help them survive theence
# - select the route
# - access all the stats
# - help them survive the assault
# - use an offline password
# - access all the stats
# - work together, and a key feature
# - help them survive the assault
# - change the route
# - reset each round
# - work together, and a option
# - use the bomb
# - access all the stats
# - access all the stats
#
#
# -- ConceptNet Features --
# - secure doors
# - represent rivers
# - understand the rules
# - estimate distances
# - explain something
# - use pieces to represent a player
# - belong to a team
# - blow something up
# - kill someone
# - pick a leader
# - make visual representations
# - get from A to B
# - shoot things
# - construct buildings
# - support a roof
#
# Game: DOTA 2
# Prompt: a 5v5 game where you protect your base while destroying enemy bases using an array of different abilities and items
# -- Human Features --
# - kill npc enemies
# - buy power ups
# - type to communicate with enemy team
# - coordinate tactics with allies
# - protect allied mobs
# - attack enemy turrets
#
# -- Transformer Features --
# action,simulation,strategy,rpg,fantasy,free to play,multiplayer,difficult,co-op,pvp,character customization,online co-op,action rpg,replay value,rts,tower defense,team-based,competitive,esports,moba,action,strategy
# arena,battle,building,character,content,delivery,dota,end,enemy,fighting,game,gold,items,map,match,mod,multiplayer,os,phase,platform,player,players,regions,sequel,stronghold,team,teams,testing,title,versions,victory,video,x
# - fight against each other in an arena
# - advance to the next stage
# - control enemy
# -royale in which the player
# - fight against enemy
# - advance through the game
# - purchase items
#
#
# -- ConceptNet Features --
# - stand on
# - pick a leader
# - tell you where you are
# - locate a place
# - name a book
# - help you find your way
# - indicate accomplishment
# - watch events
# - secure valuables
# - protect posessions
# - plan a road trip
# - search for a destination
# - stand upon
# - find the treasure
# - hold a large conference
#
# Game: THE LEGEND OF ZELDA: BREATH OF THE WILD
# Prompt: an open-world exploration game in a post-apocalyptic fantasy world where you can climb anything and destroy everything
# -- Human Features --
# - explore the wilds
# - battle towering enemies
# - think quickly and develop the right strategies
# - gather ingredients
# - earn special items
# - bundle up with warmer clothes
#
# -- Transformer Features --
# action,adventure,role-playing
# adventure,air,attack,beasts,boundary,breath,clothes,clothing,corner,desert,destinations,devices,discovery,effects,elixirs,enemies,example,exploration,fields,food,forests,game,games,gear,heat,hunt,ingredients,items,journey,kingdom,landscape,legend,method,mountain,one,order,outfits,path,peaks,puzzles,rewards,search,series,shapes,sizes,stealthier,strategies,strategy,towers,traps,travel,variety,way,ways,weaponry,wild,wilderness,wilds,world
# - find your way
# - Solve a variety
# - plan your attack
# - Travel to a variety of forests and field
# - make weapons
# - change into three different outfits
# - Become the new king
# - create new outfits
# - Explore the wilds
# - need to manage your time
# - discover new ways
# - find your way
# - learn new recipes
# - learn new combat
# - Explore a whole new world
# - become the king
# - have to think on your own path
# - learn new ways
# - find a path
# - help you on your adventure
# - Become the new king
# - discover theportation
# - become the king
# - take your breath
# - find the way
# - learn new combat
#
#
# -- ConceptNet Features --
# - time food cook with a timer
# - become moldy
# - elevate one 's mood
# - taste salty
# - shre into pieces of confetti
# - house a king
# - prevent starvation
# - indicate a border
# - protect your skin from the sun
# - find shells on a shoreline sometimes
# - hope for peace
# - live on
# - smell moldy if leave wet
# - cook or uncooked
# - provide comfort
#
# Game: ALCHEMY PRINCESS
# Prompt: an RPG about a princess who collects swords and flowers to turn into potions and is secretly a frog
# -- Human Features --
# - fight sludge monsters in the swamp
# - discover new alchemy recipes
# - identify new flora and fauna
# - explore the ruined castle
# meet new animal friends
# find the antidote to your curse
#
# -- Transformer Features --
# atmospheric,fantasy,colorful,early access,cute,relaxing,family friendly,open world,sandbox,crafting,nature,life sim,farming sim,capitalism,agriculture,cozy,wholesome,adventure,rpg
# alchemy,areas,bags,biomes,combinations,components,create,creations,experience,experiments,exploration,flowers,furniture,game,garden,gardening,gardens,gold,home,imagination,ingredients,kinds,land,mechanics,objects,piece,plants,potions,recipes,sandbox,seed,shop,storemanage,tools,trees,variety,villagers,world,princess,collects,swords,flowers,turn,potions,secretly,frog
# - use plants
# - create potions
# - grow your own plants
# - explore the land
# - make your own unique potions
# - create unique potions
# - use plants
# - grow your own gardens
# - turn your imagination
# - create unique gardens
# - create potions
# - make your own unique potions
# - make potions
# - create potions! lushflowerakura : a gardens
# - use to make your own unique plants
# - sell your creations
# - sell your creations
# - grow your own garden
# - restore acients
# - explore a mysterious and mysterious world
# - use to create potions
# - sell them to theCollects
# - make potions
# - use your imagination
# - grow your own garden
# - make potions
# - Take what you've collected back to the shop
# - turn a normal humanulp into gold
# - grow your own garden
# - make your own unique potions
# - explore a huge world
# - Take on a variety
# - make your own potions
# - create potions
#
#
# -- ConceptNet Features --
# - discover the world
# - make foods
# - live on
# - grow on trees too
# - reach towards the sky
# - appear further than they really are
# - trust that fire will harm them
# - sell your products to
# - wall you in
# - shade people sit under them
# - make wood pulp
# - buy and sell things
# - buy items
# - feel better
# - sense their environment
#
# Game: THE ONIGIRI DORM
# Prompt: a collaboritive cooking game where you make and sell onigiri in your college dorm room
# -- Human Features --
# - make onigiri on the weekends
# - set your own prices
# - buy new meats and veggies
# - decorate your dorm room
# - pay off your tuition
# - hire friends and roommates part-time
#
# -- Transformer Features --
# casual,singleplayer,simulation,colorful,multiplayer,cute,funny,family friendly,difficult,co-op,great soundtrack,local multiplayer,local co-op,4 player local,split screen,co-op campaign,cooking,action,cooking
# -,actions,baying,bowels,challenge,characters,chef,chefs,co,cooking,couch,customers,danger,dishes,ed,error,evil,fan,floe,food,fun,game,gauntlet,head,heat,huff,ice,journey,kitchen,kitchens,knives,land,level,levels,limits,master,mettle,modes,mushroom,op,operation,order,orders,ordination,part,pirate,pizza,player,players,quest,range,ship,skills,solo,steaks,super,t,team,teams,top,trucks,underworld,variety,ways,whites,world,collaboritive,make,sell,onigiri,college,dorm,room
# - push your skills of co
# - become the most effective and ultimate team
# - push your skills of co
# - take part
# - dust off your chef
# - communicate and co - ordinate their actions
# - Take part
# - dust off your chef
# - prepare, cook and serve up a variety
# - - live the journey
# - communicate and co - ordinate their actions
# - Play solo
# - take part
# - Take part
# - get ready to enter the kitchen
# - come out on top
# - come out on top
# - take it on a ghostly gauntlet
# - come out on top
# - become master
# - engage in hard boiled head
# - engage in hard boiled head
#
#
# -- ConceptNet Features --
# - cut things
# - become liquid
# - move the air
# - bread the cutlets
# - travel over water
# - ensure that a wall is vertical
# - swim on water
# - cool yourself
# - cook food
# - pull trailors with cargo in them
# - head the ball
# - reading , sleep , eat in
# - attempt to win
# - cure a headache
# - cook a gourmet meal
#
# Game: HOVERDECK 209X
# Prompt: a retro-futuristic cyberpunk skateboarding game where you hack corporations, the robot police, and the street gangs
# -- Human Features --
# - hack the corpo suits
# - vandalize properties with graffiti
# - find secret hideouts
# - race the street gangs
# - upgrade your bioware tech
# - skate the streets of the city
#
# -- Transformer Features --
# 3d,colorful,platformer,family friendly,sports,difficult,stylized,2d platformer,cartoony,character customization,hand-drawn,3d platformer,procedural generation,surreal,2.5d,precision platformer,competitive,skateboarding,action,cyberpunk,skateboarding
# accessibility,action,arms,array,battle,bee,board,brim,challenges,character,characters,compilation,controls,cruise,curb,depth,entry,expression,fear,featurestake,flops,freedom,friend,friends,gameplay,globe,gods,grabs,grind,hand,haven,judgement,leagues,levels,locations,looks,mastery,method,millions,missions,mode,moves,opportunities,paths,personality,platformer,player,players,quest,quests,rewards,ride,rivals,sandbox,score,series,side,signature,skate,skills,state,streets,studio,style,system,tracks,trick,tricks,trip,utopia,way,world,retro-futuristic,hack,corporations,robot,police,street,gangs
# - choose their look
# - choose their personality
# - Ride your private jet
# - experience the iconic grind
# - get a high score
# - Get instant access
# - ride their way
# - Experience the series's most iconic locations and quests
# - Experience the rich and immersive world
# - have to master the art
# - test your skills
# - grind your way
# - Explore a vast and rich world
# - Get a ride
# - master the deep combo system
# - complete secret missions
# - ride their way
# - Grab a friend
# - ride like a local, online multiplayer team
# - get theirarms
# - Ride like a local through a series of levels
# - Grab a friend's hand
# - test the most hardcore and timer friendly game
# - master the deep combo system
# - ride your way
# - see who comes out on top!arms
# - have access
#
#
# -- ConceptNet Features --
# - needle you
# - corner a suspect
# - carry a gun while at work
# - reduce costs
# - cut the mustard
# - give a gift to a friend
# - defeat an enemy
# - give money to each other
# - tail a suspect
# - organize a project
# - joke with
# - live in
# - cause change
# - walk and talk
# - play science fiction games

# %% [markdown]
# #### EXTRAS

# %%
for game in fake_games:
    print(f"Getting features for {game['name']}")
    p = 0.8
    k = 100
    t = 0.99
    arg_set = {'top_k':k,'top_p':p, 'temperature':t}
    print(predictTrans2(game['tags'], game['entities'], arg_set).split("\n"))
# Out:
# Getting features for ALCHEMY PRINCESS
# k 100, p: 0.8, temp: 0.99
# ['atmospheric,fantasy,colorful,early access,cute,relaxing,family friendly,open world,sandbox,crafting,nature,life sim,farming sim,capitalism,agriculture,cozy,wholesome,adventure', 'alchemy,areas,bags,biomes,combinations,components,create,creations,experience,experiments,exploration,flowers,furniture,game,garden,gardening,gardens,gold,home,imagination,ingredients,kinds,land,mechanics,objects,piece,plants,potions,recipes,sandbox,seed,shop,storemanage,tools,trees,variety,villagers,world', '- unleash your imagination', '- explore, fill in hidden areas', '- discover new plants', '- fill up your shop', '- create unique gardens', '- explore the vast world', '- use plants', '- combine ingredients', '- Grow plants', '- explore a vast world', '- explore new ingredients', '- Use plants', '- create your own unique garden', '- use to create many kinds', '- create unique gardens', '- use plants', '- use plants', '- explore the world', '- create new plants', '- create potions', '- create gardens', '- combine ingredients', '- explore a huge variety', '- create unique gardens', '']
# Getting features for THE ONIGIRI DORM
# k 100, p: 0.8, temp: 0.99
# ['casual,singleplayer,simulation,colorful,multiplayer,cute,funny,family friendly,difficult,co-op,great soundtrack,local multiplayer,local co-op,4 player local,split screen,co-op campaign,cooking,action', '-,actions,baying,bowels,challenge,characters,chef,chefs,co,cooking,couch,customers,danger,dishes,ed,error,evil,fan,floe,food,fun,game,gauntlet,head,heat,huff,ice,journey,kitchen,kitchens,knives,land,level,levels,limits,master,mettle,modes,mushroom,op,operation,order,orders,ordination,part,pirate,pizza,player,players,quest,range,ship,skills,solo,steaks,super,t,team,teams,top,trucks,underworld,variety,ways,whites,world', '- push your skills of co', '- enter the kitchen', '- battle yourcrew', '- come out on top', '- come out on top', '- come out on top', '- saut ed', '- save it! In Overcooked players', '- save it! In Overcooked players', '- save it! In Overcooked players', '- prepare, cook and serve up a variety', '- dust off your chef', '- dust off your chef', '- become master', '- test the mettle', '- become master', '- take part', '- dust off your chef', '- prepare, cook and serve up a variety', '- saut ed', '- enter the kitchen', '- engage in hard boiled head', '- dust off your chef', '- save it! In Overcooked players', '- saut ed', '- work together in order', '- save it! In Overcooked players', '- Sharpen your knives', '- saut ed', '- come out on top', '']
# Getting features for HOVERDECK 209X
# k 100, p: 0.8, temp: 0.99
# ['3d,colorful,platformer,family friendly,sports,difficult,stylized,2d platformer,cartoony,character customization,hand-drawn,3d platformer,procedural generation,surreal,2.5d,precision platformer,competitive,skateboarding,action', 'accessibility,action,arms,array,battle,bee,board,brim,challenges,character,characters,compilation,controls,cruise,curb,depth,entry,expression,fear,featurestake,flops,freedom,friend,friends,gameplay,globe,gods,grabs,grind,hand,haven,judgement,leagues,levels,locations,looks,mastery,method,millions,missions,mode,moves,opportunities,paths,personality,platformer,player,players,quest,quests,rewards,ride,rivals,sandbox,score,series,side,signature,skate,skills,state,streets,studio,style,system,tracks,trick,tricks,trip,utopia,way,world', '- compete with rivals', '- Show off your style', '- Unlock a vast array', '- compete against rivals', '- show everyone whobrandishes the skateboard', '- show the world', '- Show off your skills', '- Challenge your friends', '- test your skills', '- Play through an expansive series', '- complete missions', '- Get access', '- compete with friends', '- Explore the streets', '- show everyone that skateboarding is an action', '- show off your skills', '- Show off your style', '- create new paths', '- have the perfect platform', '- complete challenges', '- show off to your friends', '- Unlock special rewards', '- Unlock a vast array', '- test your skills', '- ride your way', '- get a legtrip', '- Show off your skills', '- have to master thesharing', '- master the unique trick', '']

# %%
fake_games[2]['cnet'].generate(10)
# Out:
# ['solve problems',
#  'meet over lunch',
#  'needle you',
#  'meet for coffee',
#  'make you happy',
#  'beat the dealer',
#  'play a game of chess',
#  'keep vehicles on the street',
#  'build something wooden with',
#  'jump on']

# %%
len(GRMOD.GAME_DATA.keys())
# Out:
# 59771
